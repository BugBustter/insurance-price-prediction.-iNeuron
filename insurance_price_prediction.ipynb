# %%
# Load Pakages Mathematical and DATA Operations
import numpy as np
import pandas as pd

# Load Pakages plotting
import matplotlib.pyplot as plt
import seaborn as sns

# Importing STYLE to set the Style
from matplotlib import style

# Load Pakages for Ignore Warnings
import warnings
warnings.filterwarnings('ignore')
sns.set()
from collections import Counter

# Load Pakages Scaling
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

# Load Pakages for Encoding
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder

# Load Pakage COLUMNTRANSFORMER to apply transformers to columns of an array.
from sklearn.compose import ColumnTransformer

# Load Pakages for Data Partetions
from sklearn.model_selection import train_test_split

# Importing Pipes for making the Pipe Flow
from sklearn.pipeline import Pipeline

# Load Pakages for Model Building
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor

# Load Pakages for Evaluation
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
from sklearn.model_selection import GridSearchCV

# Importing WIDGETS to Build a WIDGETS
import ipywidgets as widgets

# Importing the DISPLAY Function to Display the widgets
from IPython.display import display

# %%
# Load Dataset
data = pd.read_csv("insurance.csv")

# %% [markdown]
# #  Exploratory Data Analysis

# %%
# Displaying the First 5-Records of data
data.head(5)
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86

# %%
# Displaying the Last 5-Records of data
data.tail(5)
# Out:
#       age     sex   bmi  children smoker     region  expenses
# 1333   50    male  31.0         3     no  northwest  10600.55
# 1334   18  female  31.9         0     no  northeast   2205.98
# 1335   18  female  36.9         0     no  southeast   1629.83
# 1336   21  female  25.8         0     no  southwest   2007.95
# 1337   61  female  29.1         0    yes  northwest  29141.36

# %%
# Displaying the Random 5-Records of data
data.sample(5)
# Out:
#      age     sex   bmi  children smoker     region  expenses
# 571   18  female  37.3         1     no  southeast   2219.45
# 799   33    male  24.8         0    yes  northeast  17904.53
# 534   64    male  40.5         0     no  southeast  13831.12
# 82    22    male  37.6         1    yes  southeast  37165.16
# 644   43    male  35.3         2     no  southeast  18806.15

# %%
print(f'-> No. of Rows: {data.shape[0]} \n-> No. of Columns: {data.shape[1]}')
# Out:
# -> No. of Rows: 1338
# -> No. of Columns: 7

# %%
# Information of Data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   expenses  1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
Numerical_Features = [i for i in data.dtypes[data.dtypes != 'object'].index]
Categorical_Features = [i for i in data.dtypes[data.dtypes == 'object'].index]
print(f'Numerical Features: {Numerical_Features} \nCategorical Features: {Categorical_Features}')
# Out:
# Numerical Features: ['age', 'bmi', 'children', 'expenses']
# Categorical Features: ['sex', 'smoker', 'region']

# %%
print(f'No. of Numerical Features: {len(Numerical_Features)} \nNo. of Categorical Features: {len(Categorical_Features)}')
# Out:
# No. of Numerical Features: 4
# No. of Categorical Features: 3

# %%
# Statistical Summary
data[Numerical_Features].describe()
# Out:
#                age          bmi     children      expenses
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.665471     1.094918  13270.422414
# std      14.049960     6.098382     1.205493  12110.011240
# min      18.000000    16.000000     0.000000   1121.870000
# 25%      27.000000    26.300000     0.000000   4740.287500
# 50%      39.000000    30.400000     1.000000   9382.030000
# 75%      51.000000    34.700000     2.000000  16639.915000
# max      64.000000    53.100000     5.000000  63770.430000

# %%
data[Categorical_Features].describe()
# Out:
#          sex smoker     region
# count   1338   1338       1338
# unique     2      2          4
# top     male     no  southeast
# freq     676   1064        364

# %%
# check unique values
for i in data.columns:
  print('*************************************',i,'*************************************')
  print(data[i].unique())
  print()
# Out:
# ************************************* age *************************************
# [19 18 28 33 32 31 46 37 60 25 62 23 56 27 52 30 34 59 63 55 22 26 35 24
#  41 38 36 21 48 40 58 53 43 64 20 61 44 57 29 45 54 49 47 51 42 50 39]
#
# ************************************* sex *************************************
# ['female' 'male']
#
# ************************************* bmi *************************************
# [27.9 33.8 33.  22.7 28.9 25.7 33.4 27.7 29.8 25.8 26.2 26.3 34.4 39.8
#  42.1 24.6 30.8 23.8 40.3 35.3 36.  32.4 34.1 31.9 28.  23.1 32.8 17.4
#  36.3 35.6 28.6 28.3 36.4 20.4 20.8 36.7 39.9 26.6 36.6 21.8 37.1 37.3
#  38.7 34.8 24.5 35.2 33.6 28.7 37.  31.8 31.7 22.9 27.4 33.7 24.7 25.9
#  22.4 39.1 36.2 24.  24.8 28.5 28.1 32.  34.  29.6 35.5 26.9 38.3 37.6
#  41.2 31.2 27.2 27.  39.5 31.3 20.  19.3 31.6 25.5 30.1 29.9 27.5 28.4
#  30.9 35.1 29.7 35.7 32.2 49.1 23.4 29.  31.4 33.9 28.8 37.4 17.8 34.7
#  26.5 22.  35.9 25.6 25.2 32.5 25.3 38.8 30.5 37.7 24.1 24.4 27.8 36.9
#  39.6 28.2 33.2 18.9 41.5 30.3 16.  33.3 29.2 26.4 30.7 41.9 32.1 30.6
#  18.1 39.3 36.1 22.3 26.7 23.2 38.1 22.2 38.4 29.1 22.1 26.8 30.  20.9
#  17.3 34.2 25.4 40.2 24.3 42.4 19.8 30.2 29.4 27.6 20.6 21.6 40.6 48.1
#  36.8 45.5 23.  22.6 37.5 38.  34.9 33.1 40.9 36.5 34.5 32.3 29.3 35.8
#  43.9 21.7 21.9 25.  30.4 21.1 32.9 24.9 31.5 18.  43.3 19.9 31.  38.2
#  47.5 23.6 17.5 20.2 17.2 23.9 39.2 27.3 16.8 46.8 29.5 32.7 33.5 43.
#  38.6 46.5 25.1 32.6 41.3 34.3 31.1 21.5 43.4 26.  44.2 26.1 39.4 40.5
#  38.9 47.4 35.4 46.7 46.2 21.4 44.8 43.1 23.5 45.4 23.7 20.7 19.6 37.8
#  19.  21.3 42.5 39.  39.7 35.  42.7 40.8 20.3 18.5 41.7 44.7 40.7 27.1
#  37.9 22.8 34.6 19.5 41.1 22.5 41.8 42.2 41.4 42.9 21.  24.2 17.7 50.4
#  47.6 43.7 44.  20.1 37.2 46.1 18.3 40.  20.5 23.3 19.2 45.3 18.7 52.6
#  47.7 19.1 42.8 18.6 45.9 44.9 40.4 17.9 53.1]
#
# ************************************* children *************************************
# [0 1 3 2 5 4]
#
# ************************************* smoker *************************************
# ['yes' 'no']
#
# ************************************* region *************************************
# ['southwest' 'southeast' 'northwest' 'northeast']
#
# ************************************* expenses *************************************
# [16884.92  1725.55  4449.46 ...  1629.83  2007.95 29141.36]

# %%
# Checking for unique values in every column
data.nunique()
# Out:
# age           47
# sex            2
# bmi          275
# children       6
# smoker         2
# region         4
# expenses    1337
# dtype: int64

# %%
#Checking the null values
data.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# expenses    0
# dtype: int64

# %%
# Getting the total sum of null values
data.isnull().sum().sum()
# Out:
# 0

# %%
# Listing the type of all columns
data.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# expenses    float64
# dtype: object

# %% [markdown]
# # Detecting the outliers

# %%
# Function for Boxplot
def Boxplot(dataset):
  for i in dataset.dtypes[dataset.dtypes != 'object'].index:
    sns.boxplot(dataset[i])
    plt.show();

Boxplot(data)

# %%
# Function for Detecting the outliers
outliers = []
def detect_outliers_iqr(data):
    data = sorted(data)
    q1 = np.percentile(data, 25)
    q3 = np.percentile(data, 75)
    # print(q1, q3)
    IQR = q3-q1
    lr_bound = q1-(1.5*IQR)
    upr_bound = q3+(1.5*IQR)
# print(lwr_bound, upr_bound)
    for i in data:
        if (i<lr_bound or i>upr_bound):
            outliers.append(i)
    return outliers# Driver code
sample_outliers = detect_outliers_iqr(data['bmi'])
print("Outliers from IQR method: ", sample_outliers)
# Out:
# Outliers from IQR method:  [47.4, 47.5, 47.6, 47.7, 48.1, 49.1, 50.4, 52.6, 53.1]

# %%
# no. of Labels of Categorical Variable
for i in Categorical_Features:
  print(f'***********{i}*********** \n{data[i].value_counts()}')
# Out:
# ***********sex***********
# sex
# male      676
# female    662
# Name: count, dtype: int64
# ***********smoker***********
# smoker
# no     1064
# yes     274
# Name: count, dtype: int64
# ***********region***********
# region
# southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: count, dtype: int64

# %%
# checking Duplicated values
Before_shape = data.shape
Duplicate = data.duplicated().sum()
data = data.drop_duplicates()
after_shape = data.shape
print(f'Orginal Shape: {Before_shape} \nNo. of Duplicates: {Duplicate}\nAfter Droping Duplicate: {after_shape}')
# Out:
# Orginal Shape: (1338, 7)
# No. of Duplicates: 1
# After Droping Duplicate: (1337, 7)

# %% [markdown]
# # Data Visualization

# %%
sns.pairplot(data)

# %%
fig, ax = plt.subplots(1,3,figsize=(18,4))
sns.swarmplot(ax=ax[0],x='sex',y='expenses',data=data,)
sns.stripplot(ax=ax[1],x='sex',y='expenses',data=data)
sns.countplot(ax=ax[2],x='sex',hue='sex',data=data)
ax[2].bar_label(ax[2].containers[0])
ax[2].bar_label(ax[2].containers[1])
plt.legend(loc='center',title='sex')
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ## It shows that count is almost equal not much difference

# %%
# Children Column
plt.figure(figsize=(8,6))
ax = sns.countplot(data.children,palette='PuRd_r')
ax.bar_label(ax.containers[0]);

# %% [markdown]
# ## This plot shows us people with zero children is more and people have 1&2 is average compared to 1&2 and 3,4,5 are less that this also decides the cost of a insurance

# %% [markdown]
# ## This plot gives us the correct information of about the people that more number of people are Non-smokers

# %%
# Gender vs Smoker
sns.stripplot(x = 'sex',y = 'expenses',data = data,hue='smoker')
plt.legend(loc = 'best')

# %%
# Region Column
plt.figure(figsize=(10,7))
ax = sns.countplot(x='region',data= data,hue='region',palette='PuRd_r')
for container in ax.containers:
    ax.bar_label(container)
plt.title("Region Details")
plt.legend(loc='upper center',title='Region')
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ## This shows we have four regions in that data is nearly normally distrubeted that one region is slightly high tha is SE

# %%
sns.violinplot(x = 'sex',y = 'age',data = data,hue = 'sex')
plt.legend(loc = 'best')
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ## In both sex peoples are near equal all the ages

# %%
plt.figure(figsize=(10,5))
ax = sns.barplot(x='region',y='expenses',data = data)
ax.bar_label(ax.containers[0])
plt.title('Region VS Expenses')
plt.show()

# %% [markdown]
# ## From this we get that SE region people have highest expense than others in this case get to know about is that region can also affect the expenses.

# %%
plt.figure(figsize=(5,6))
ax = sns.barplot(x='smoker',y='expenses',data = data)
ax.bar_label(ax.containers[0])
plt.title('Smoker VS Expenses')
plt.show()

# %% [markdown]
# ## This shows that person who smokes that their expense higher.

# %%
plt.figure(figsize=(5,6))
ax = sns.barplot(x='sex',y='expenses',hue='smoker',data = data)
for container in ax.containers:
    ax.bar_label(container)
plt.title('Smoker Expenses Gender Based')
plt.show()

# %% [markdown]
# ## This plot shows that smoker male has higher expense then female but at the same time non smoker female has slightly higher expense than a non smoker male.

# %% [markdown]
# ## 1st Plot shows the previous visualization that SE has higher expense but male has higher expense in most categories
#
# ## 2nd plot shows non smoker in NE has a higher expense compare to others.

# %%
# Distribution of Age Value

sns.set()
plt.figure(figsize=(10,6))
sns.distplot(data['age'])
plt.title('Age Distribution')
plt.show()

# %% [markdown]
# ## Now we See the Distribution the age value is 10 to 70 we have more density in the age of 20 & 21 other than that the age is distributed normally
#
# ## It shows more no of people in our dataset is 20 & 21 age

# %%
# Distribution of BMI Value

sns.set()
plt.figure(figsize=(10,6))
sns.distplot(data['bmi'])
plt.title('BMI Distribution')
plt.show()

# %% [markdown]
# ## It shows that BMI is nearly normally distributed,But normal BMI range for a person is 18.5 to 24.9,it shows the lot people are over weight it can affect a insurance cost

# %%
# Distribution of Expenses Value

sns.set()
plt.figure(figsize=(10,6))
sns.distplot(data['expenses'])
plt.title('Expense Distribution')
plt.show()

# %% [markdown]
# ## This Distribution shows us that data is not normally distributed but we have more values in lower expenses that gives cost is not so to high

# %% [markdown]
# # Preprocessing

# %%
# Creating a function
def preprocess_inputs(df):
    df = df.copy()

    # Split df into X and Y
    y = df['expenses']
    x = df.drop('expenses', axis=1)

    # Train-test split
    x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=.7, shuffle = True, random_state=101)

    return x_train, x_test, y_train, y_test

# %%
x_train, x_test, y_train, y_test = preprocess_inputs(data)

# %%
x_train.head()
# Out:
#      age     sex   bmi  children smoker     region
# 405   52  female  38.4         2     no  northeast
# 836   36    male  31.5         0     no  southwest
# 483   51  female  39.5         1     no  southwest
# 319   32    male  37.3         1     no  northeast
# 957   24    male  26.8         1     no  northwest

# %%
y_train.head()
# Out:
# 405    11396.90
# 836     4402.23
# 483     9880.07
# 319     4667.61
# 957    12609.89
# Name: expenses, dtype: float64

# %% [markdown]
# # Building a Pipeline & Training

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor

# Assigning the categorical columns
nominal_features = ['sex', 'smoker', 'region']

# It will transform the categorical values and skip the binary values
nominal_transformer = Pipeline(steps=[
    ('onehot', OneHotEncoder(sparse_output=False, drop='if_binary'))
])

# Preprocessor tells the model which values to target
# 'passthrough' will pass binary columns; it won't drop them
preprocessor = ColumnTransformer(transformers=[
    ('nominal', nominal_transformer, nominal_features)
], remainder='passthrough')

# Building models with Scaler & Pipeline
KNN_model = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('scaler', StandardScaler()),
    ('regressor', KNeighborsRegressor())
])

RF_model = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('scaler', StandardScaler()),
    ('regressor', RandomForestRegressor())
])

GB_model = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('scaler', StandardScaler()),
    ('regressor', GradientBoostingRegressor())
])

# %%
# GradientBoostingRegressor

# %%
GB_model.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('nominal',
#                                                   Pipeline(steps=[('onehot',
#                                                                    OneHotEncoder(drop='if_binary',
#                                                                                  sparse_output=False))]),
#                                                   ['sex', 'smoker',
#                                                    'region'])])),
#                 ('scaler', StandardScaler()),
#                 ('regressor', GradientBoostingRegressor())])

# %%
y_pred_GB = GB_model.predict(x_test)

# %%
y_pred_GB
# Out:
# array([ 7244.35902298,  3848.39800059,  5035.64427465, 11192.4950453 ,
#         7504.20680672,  2617.2617315 , 15218.98677152,  6581.90253468,
#        11381.83740075,  5909.01685253,  7359.63039315, 11417.41405381,
#        16753.22321671, 13735.07682109,  7684.34962842, 42974.62698258,
#         8721.169348  , 10619.97802291, 10780.46510437, 10950.79283934,
#         2617.2617315 , 36154.37591844, 24565.30043358, 13411.152626  ,
#        35478.98481056, 18266.95285316, 11175.71184785,  9126.2814226 ,
#         7868.3202398 ,  7970.15625188,  2541.36951905,  9024.22756174,
#         3375.06378907,  5041.21684475,  2059.21285357, 12576.38529502,
#         8861.17977492, 11534.8126876 , 14843.41577318,  2579.07842766,
#        11969.85160461, 39293.54685737, 11039.05650504, 10036.11698224,
#        27899.8284892 ,  2442.87898574, 19501.81613929,  6278.42634783,
#        42970.73813492,  5833.97026794,  1142.10785646,  3731.23325687,
#         6926.29336031,  7698.04796107,  5318.8187074 , 14379.49366168,
#        22090.15108546, 13323.35392581,  5656.54698043,  6399.26157069,
#        10921.16597231,  9588.83776109, 21466.48380764, 10876.97847594,
#        16652.72347593, 12930.07487162,  4675.68694372,  6761.84800695,
#        13978.71811364, 45080.80175558, 37800.69079087, 37061.13244205,
#         6008.00431068,  3419.85341394,  6412.60062813, 42928.1937655 ,
#        13658.01278641, 47819.96666414,  5015.56989285,  7684.58323937,
#        13842.82568065,  3526.76272993, 12528.82012165,  7728.73580483,
#         7984.15699087,  9262.40148462,  8205.38395314,  1224.12878195,
#         7985.1513342 ,  7879.7044242 ,  6083.91807092,  6079.86064079,
#         6601.57412504,  7142.43908785, 42974.62698258,  2555.9829597 ,
#         4791.99220337, 45750.82860341,  3903.13493909, 11925.78140843,
#        16998.30411108,  9391.95476523,  6172.98259353,  6530.93812644,
#        14689.17820888, 45968.23350792, 14815.28426437, 13322.54002846,
#        12054.71547978, 13536.32482726, 22329.93476079,  2527.29449542,
#        13588.54115073, 45927.7179967 ,  4817.54239212,  6351.45541702,
#         6420.58529   ,  8272.15403655,  4244.54565124, 37430.90453231,
#         6313.54713054, 10430.3838819 ,  8442.24163029, 35352.94177244,
#        20338.07065832, 10600.84255551,  8972.47480762, 12706.49305421,
#        10786.1771347 ,  4164.36010437,  7300.08550871,  5827.19167146,
#         6332.24207725, 10906.06991551, 36086.77321948,  6837.95014757,
#        15446.34656758, 20024.50694067,  6953.22666258, 12176.6520987 ,
#         6211.36036936,  5542.88232832,  8744.81852289,  4420.2762695 ,
#         7852.66623862,  9095.21375977, 38419.94541409, 16865.85022649,
#        10815.61574964,  6327.18058316, 12156.20879081,  6164.79186658,
#         8981.8596003 ,  7295.84952233,  3674.27604943, 13043.61231076,
#        10642.2382546 , 24026.99248003, 12051.76938569, 16720.64288186,
#         4329.31519264, 13773.04270038, 11642.1796545 ,  5944.15625428,
#         4770.14454117, 23586.7463384 , 14564.57257721, 10788.6635077 ,
#        14875.47175682, 35317.24520451,  7066.59469139,  2815.29503451,
#        12715.1886752 ,  4629.451314  , 12846.19435446, 14745.93078377,
#         2748.87983321, 11838.67922768, 16387.32947977,  3905.45290956,
#        13317.0629872 ,  7310.30521665,  3887.08396996,  6291.93530946,
#         5253.8806893 ,  2921.48560213,  5798.09117961,  6291.84994986,
#         8972.47480762, 14831.4180305 ,  5852.04462987, 12242.87786422,
#        12484.03211166, 19073.97744319,  9110.02045845, 45362.36477204,
#        11641.84871133, 10788.21522156, 13532.25477367,  5764.73130037,
#        42436.64340572,  5933.5138065 , 17954.81009436,  5500.93393344,
#         3731.23325687, 14796.72114349, 10409.6344288 ,  3409.71280161,
#        12463.00980279,  6867.00962571, 38474.69538073,  5802.53544448,
#         3263.26573493, 18621.71153984,  7580.91661682, 35947.34644133,
#         5652.69920881, 13477.83426978])

# %%
# MEAN
y_pred_GB_m = np.mean((y_test - y_pred_GB)**2)
y_pred_GB_m
# Out:
# 22270249.515098058

# %%
# RMSE
np.sqrt(y_pred_GB_m)
# Out:
# 4719.136522193235

# %%
# Error for our model
yt_m1 = ((y_test - y_pred_GB)**2)
yt_m1
# Out:
# 44      1.356501e+06
# 134     1.935404e+06
# 981     2.865507e+05
# 619     2.293022e+05
# 1239    1.819677e+07
#             ...
# 375     3.454401e+05
# 687     4.588878e+06
# 103     2.505159e+07
# 1138    3.796065e+06
# 715     1.771200e+06
# Name: expenses, Length: 402, dtype: float64

# %%
# Error between ytest & ytest mean and squaring it
yt_m_diff = ((y_test - y_test.mean())**2)
yt_m_diff
# Out:
# 44      4.347345e+07
# 134     1.043646e+08
# 981     6.679417e+07
# 619     3.839524e+06
# 1239    8.901300e+07
#             ...
# 375     2.873882e+07
# 687     5.233597e+07
# 103     3.337593e+08
# 1138    8.043866e+07
# 715     2.768236e+05
# Name: expenses, Length: 402, dtype: float64

# %%
# Sum of the squared error for baseline model
yt1 = np.sum(yt_m_diff)
yt1
# Out:
# 56334917560.88686

# %%
# Sum of the squared error for our model
yt2 = np.sum(yt_m1)
yt2
# Out:
# 8952640305.06942

# %%
# R-Squared Error
R2 = 1-(yt2/yt1)
R2
# Out:
# 0.8410818601910015

# %%
r2_score(y_test, y_pred_GB)
# Out:
# 0.8410818601910015

# %%
# KNN

# %%
KNN_model.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('nominal',
#                                                   Pipeline(steps=[('onehot',
#                                                                    OneHotEncoder(drop='if_binary',
#                                                                                  sparse_output=False))]),
#                                                   ['sex', 'smoker',
#                                                    'region'])])),
#                 ('scaler', StandardScaler()),
#                 ('regressor
# %%
# MEAN
y_pred_KNN_m = np.mean((y_test - y_pred_KNN)**2)
y_pred_KNN_m
# Out:
# 32062335.073065326

# %%
# RMSE
np.sqrt(y_pred_KNN_m)
# Out:
# 5662.361263030232

# %%
y_test.describe()
# Out:
# count      402.000000
# mean     12673.110274
# std      11852.682342
# min       1121.870000
# 25%       4529.420000
# 50%       8721.255000
# 75%      14225.402500
# max      63770.430000
# Name: expenses, dtype: float64

# %%
y_train.mean()
# Out:
# 13539.67411764706

# %%
y_test.mean()
# Out:
# 12673.11027363184

# %%
# Error between ytest & ytest mean and squaring it
yt_m_diff = ((y_test - y_test.mean())**2)
yt_m_diff
# Out:
# 44      4.347345e+07
# 134     1.043646e+08
# 981     6.679417e+07
# 619     3.839524e+06
# 1239    8.901300e+07
#             ...
# 375     2.873882e+07
# 687     5.233597e+07
# 103     3.337593e+08
# 1138    8.043866e+07
# 715     2.768236e+05
# Name: expenses, Length: 402, dtype: float64

# %%
# Sum of the squared error for baseline model
yt1 = np.sum(yt_m_diff)
yt1
# Out:
# 56334917560.88686

# %%
# Error for our model
yt_m1 = ((y_test - y_pred_KNN)**2)
yt_m1
# Out:
# 44      9.219149e+05
# 134     2.376422e+07
# 981     7.839332e+01
# 619     1.035933e+06
# 1239    1.331389e+05
#             ...
# 375     4.224373e+07
# 687     2.780516e+07
# 103     1.977092e+07
# 1138    2.160892e+05
# 715     5.905133e+06
# Name: expenses, Length: 402, dtype: float64

# %%
# Sum of the squared error for our model
yt2 = np.sum(yt_m1)
yt2
# Out:
# 12889058699.372261

# %%
# R-Squared Error
R2 = 1-(yt2/yt1)
R2
# Out:
# 0.7712065756474793

# %%
r2_score(y_test, y_pred_KNN)
# Out:
# 0.7712065756474793

# %%
# Random Forest
RF_model.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('nominal',
#                                                   Pipeline(steps=[('onehot',
#                                                                    OneHotEncoder(drop='if_binary',
#                                                                                  sparse_output=False))]),
#                                                   ['sex', 'smoker',
#                                                    'region'])])),
#                 ('scaler', StandardScaler()),
#                 ('regressor', RandomForestRegressor())])

# %%
y_pred_RF = RF_model.predict(x_test)

# %%
y_pred_RF
# Out:
# array([ 8702.0782,  5056.9297,  9588.3368, 11697.1332,  7970.0783,
#         2062.8542, 13445.3441,  5664.2194, 11369.8938,  5373.5562,
#         6520.7778, 10411.769 , 14510.9693, 12906.6675,  7025.815 ,
#        43615.0707,  7810.0258,  9227.023 , 10680.3645, 10720.4988,
#         2062.8542, 36236.6901, 25390.4898, 12368.9255, 33749.4864,
#        17156.1832, 11253.4468,  9714.0155,  7956.2421,  9329.4721,
#         2363.0744,  8876.6083,  2202.0606,  4336.3907,  2012.7379,
#         7143.0573,  9306.3544, 11996.7256, 14483.6189,  2197.1126,
#        12185.5764, 39857.0685, 12752.1363,  9314.4182, 26445.2231,
#         2176.2544, 18861.0295, 10529.3175, 42679.8322,  7659.5287,
#         1263.1857,  3418.5041,  7103.1422,  6383.6988,  5623.8742,
#        13620.865 , 20681.1233, 11873.6659,  6232.6527,  7651.3174,
#        12178.7675, 13944.5844, 21481.9812,  9815.1208, 15411.6315,
#        11786.326 ,  4303.5131,  6383.699 , 13859.0806, 46583.2803,
#        37309.267 , 37772.3295,  8035.8328,  2077.8753,  5597.8565,
#        43899.0891, 14301.3784, 47285.0107,  5609.7235, 11913.8869,
#        13469.4979,  2775.0753, 12075.611 , 11234.7821,  6837.9918,
#         2406.8389, 12946.0252, 46143.3949,  3537.8587,  6230.6114,
#         5563.3651,  7527.8111,  7974.9645, 38832.6799,  8462.9803,
#        12881.9301,  8180.4657, 34105.6086, 21073.8552, 10159.7738,
#         9118.7756, 14571.4496, 10674.4382,  4289.7686,  7222.145 ,
#         5124.7076,  6323.3646,  9298.0642, 34334.1554,  6249.9658,
#        14776.8713, 20852.8204,  6949.6236, 12460.9707,  5795.7079,
#        13893.1586,  7706.8271,  4448.7405,  7368.4129,  8165.7669,
#        39406.2973, 14905.6017,  9469.601 ,  5566.2959, 10862.3929,
#         5139.2282,  7545.9238,  6618.6024,  5705.7365, 15343.343 ,
#         9628.4253, 24112.4322, 10674.6498, 16346.9807,  4400.9704,
#        14225.3912, 11123.56  ,  4887.3182,  4843.9681, 21039.591 ,
#        13493.6718, 12004.8709, 13914.5545, 36508.5606,  6217.2586,
#         2771.9169, 12088.0952,  6691.1721, 12620.0308, 13561.9344,
#         2105.7073, 11581.6436, 16307.8806,  6083.4728, 12816.9607,
#         6788.7025,  2481.4382,  6951.2632,  3533.6743,  2271.1706,
#         9819.4339,  7411.3759,  8973.5891, 15543.892 ,  8150.3885,
#        11879.1702, 18160.7343, 19355.6538,  8512.9808, 47690.076 ,
#        11333.6111, 10358.345 , 13319.6329,  3742.6635, 41745.9786,
#         6664.8317, 18294.0616,  5051.943 ,  4053.121 , 18078.6811,
#         9449.8685,  2329.9477, 17685.906 ,  9092.8417, 39322.5023,
#         6399.4696,  4744.2487, 19638.2521,  8787.4561, 32080.4397,
#         5106.3565, 12751.4031])

# %%
y_test
# Out:
# 44       6079.67
# 134      2457.21
# 981      4500.34
# 619     10713.64
# 1239     3238.44
#           ...
# 375     18033.97
# 687      5438.75
# 103     30942.19
# 1138     3704.35
# 715     12146.97
# Name: expenses, Length: 402, dtype: float64

# %%
# Calculating the error between y-test & y-pred
y_test - y_pred_RF
# Out:
# 44     -2622.4082
# 134    -2599.7197
# 981    -5087.9968
# 619     -983.4932
# 1239   -4731.6383
#           ...
# 375    -1604.2821
# 687    -3348.7061
# 103    -1138.2497
# 1138   -1402.0065
# 715     -604.4331
# Name: expenses, Length: 402, dtype: float64

# %%
# MEAN
y_pred_RF_m = np.mean((y_test - y_pred_RF)**2)
y_pred_RF_m
# Out:
# 23951778.735847786

# %%
# RMSE
np.sqrt(y_pred_RF_m)
# Out:
# 4894.055448791706

# %%
y_train.mean()
# Out:
# 13539.67411764706

# %%
y_test.mean()
# Out:
# 12673.11027363184

# %%
# Error between ytest & ytest mean and squaring it
yt_m_diff = ((y_test - y_test.mean())**2)
yt_m_diff
# Out:
# 44      4.347345e+07
# 134     1.043646e+08
# 981     6.679417e+07
# 619     3.839524e+06
# 1239    8.901300e+07
#             ...
# 375     2.873882e+07
# 687     5.233597e+07
# 103     3.337593e+08
# 1138    8.043866e+07
# 715     2.768236e+05
# Name: expenses, Length: 402, dtype: float64

# %%
# Sum of the squared error for baseline model
yt1 = np.sum(yt_m_diff)
yt1
# Out:
# 56334917560.88686

# %%
# Error for our model
yt_m1 = ((y_test - y_pred_RF)**2)
yt_m1
# Out:
# 44      6.877025e+06
# 134     6.758543e+06
# 981     2.588771e+07
# 619     9.672589e+05
# 1239    2.238840e+07
#             ...
# 375     2.573721e+06
# 687     1.121383e+07
# 103     1.295612e+06
# 1138    1.965622e+06
# 715     3.653394e+05
# Name: expenses, Length: 402, dtype: float64

# %%
# Sum of the squared error for our model
yt2 = np.sum(yt_m1)
yt2
# Out:
# 9628615051.81081

# %%
# R-Squared Error
R2 = 1-(yt2/yt1)
R2
# Out:
# 0.8290826459201934

# %%
models = [('KNN', np.sqrt(y_pred_KNN_m), r2_score(y_test, y_pred_KNN)),
          ('RF', np.sqrt(y_pred_RF_m), r2_score(y_test, y_pred_RF)),
          ('GB', np.sqrt(y_pred_GB_m), r2_score(y_test, y_pred_GB))
         ]

# %%
r2_score(y_test,y_pred_RF)
# Out:
# 0.8290826459201934

# %%
predict = pd.DataFrame(data = models, columns=['Model', 'RMSE', 'R2_Score'])
predict
# Out:
#   Model         RMSE  R2_Score
# 0   KNN  5662.361263  0.771207
# 1    RF  4894.055449  0.829083
# 2    GB  4719.136522  0.841082

# %%
plt.figure(figsize=(12,7))
predict.sort_values(by=['R2_Score'], ascending=False, inplace=True)

sns.barplot(x='R2_Score', y='Model',data = predict, palette='Reds')
plt.xlabel('R2_Score')
plt.ylabel('Model')
plt.show()

# %% [markdown]
# ## From all the model GradientBoostingRegressor performs well

# %%
y = data['expenses']
x = data.drop('expenses', axis=1)

# %%
GB_model.fit(x, y)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('nominal',
#                                                   Pipeline(steps=[('onehot',
#                                                                    OneHotEncoder(drop='if_binary',
#                                                                                  sparse_output=False))]),
#                                                   ['sex', 'smoker',
#                                                    'region'])])),
#                 ('scaler', StandardScaler()),
#                 ('regressor', GradientBoostingRegressor())])

# %%
import joblib

# %%
joblib.dump(GB_model,'model_jobliob_gr')
# Out:
# ['model_jobliob_gr']

# %%
model = joblib.load('model_jobliob_gr')
model
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('nominal',
#                                                   Pipeline(steps=[('onehot',
#                                                                    OneHotEncoder(drop='if_binary',
#                                                                                  sparse_output=False))]),
#                                                   ['sex', 'smoker',
#                                                    'region'])])),
#                 ('scaler', StandardScaler()),
#                 ('regressor', GradientBoostingRegressor())])

# %%
data = {'age':40,'sex':'male','bmi':40.30,'children':4,'smoker':'yes','region':'southwest'}
df = pd.DataFrame(data,index = [0])
df
# Out:
#    age   sex   bmi  children smoker     region
# 0   40  male  40.3         4    yes  southwest

# %%
model.predict(df)
# Out:
# array([41881.471169])

# %% [markdown]
# # INTERACTIVE WIDGETS

# %%
x_train
# Out:
#      age     sex   bmi  children smoker     region
# 405   52  female  38.4         2     no  northeast
# 836   36    male  31.5         0     no  southwest
# 483   51  female  39.5         1     no  southwest
# 319   32    male  37.3         1     no  northeast
# 957   24    male  26.8         1     no  northwest
# ..   ...     ...   ...       ...    ...        ...
# 575   58  female  27.2         0     no  northwest
# 974   26    male  35.4         0     no  southeast
# 75    57    male  34.0         0     no  northwest
# 600   18  female  39.2         0     no  southeast
# 864   51    male  25.4         0     no  southwest
#
# [935 rows x 6 columns]

# %%
{column : list(x_train[column].unique()) for column in x_train.select_dtypes('object').columns}
# Out:
# {'sex': ['female', 'male'],
#  'smoker': ['no', 'yes'],
#  'region': ['northeast', 'southwest', 'northwest', 'southeast']}

# %%
x_train.describe()
# Out:
#               age         bmi    children
# count  935.000000  935.000000  935.000000
# mean    39.180749   30.619679    1.100535
# std     14.027140    6.178380    1.191759
# min     18.000000   16.800000    0.000000
# 25%     27.000000   25.950000    0.000000
# 50%     39.000000   30.200000    1.000000
# 75%     51.000000   34.650000    2.000000
# max     64.000000   53.100000    5.000000

# %%
widgets.IntSlider()
# Out:
# IntSlider(value=0)

# %%
widgets.FloatSlider()
# Out:
# FloatSlider(value=0.0)

# %%
widgets.ToggleButtons()
# Out:
# ToggleButtons(options=(), value=None)

# %%
widgets.IntSlider(
    value = 18,
    min = 10,
    max = 60,
    step = 1,
    description = 'AGE:'
)
# Out:
# IntSlider(value=18, description='AGE:', max=60, min=10)

# %%
widgets.FloatSlider(
    value = 30,
    min = 15,
    max = 54,
    step = 0.01,
    description = 'BMI: '
)
# Out:
# FloatSlider(value=30.0, description='BMI: ', max=54.0, min=15.0, step=0.01)

# %%
widgets.IntSlider(
    value = 1,
    min = 0,
    max = 10,
    step = 1,
    description ="CHILDREN'S:"
)
# Out:
# IntSlider(value=1, description="CHILDREN'S:", max=10)

# %%
widgets.ToggleButtons(
    options = ['female','male'],
    description = 'SEX: '
)
# Out:
# ToggleButtons(description='SEX: ', options=('female', 'male'), value='female')

# %%
widgets.ToggleButtons(
    options = ['no','yes'],
    description = 'SMOKER: '
)
# Out:
# ToggleButtons(description='SMOKER: ', options=('no', 'yes'), value='no')

# %%
widgets.Dropdown(
    options = ['northwest', 'southwest', 'northeast', 'southeast'],
    description = 'REGION: '
)
# Out:
# Dropdown(description='REGION: ', options=('northwest', 'southwest', 'northeast', 'southeast'), value='northwes…

# %%
Age_widget = widgets.IntSlider(
    value = 18,
    min = 10,
    max = 60,
    step = 1,
    description = 'AGE:'
)

Bmi_widget = widgets.FloatSlider(
    value = 30,
    min = 15,
    max = 54,
    step = 0.01,
    description = 'BMI: '
)


Childrens_widget = widgets.IntSlider(
    value = 1,
    min = 0,
    max = 10,
    step = 1,
    description ="CHILDREN'S:"
)


Sex_widget = widgets.ToggleButtons(
    options = ['female','male'],
    description = 'SEX: '
)


Smoker_widget = widgets.ToggleButtons(
    options = ['no','yes'],
    description = 'SMOKER: '
)


Region_widget = widgets.Dropdown(
    options = ['northwest', 'southwest', 'northeast', 'southeast'],
    description = 'REGION: '
)



widgets.Button(
    description = 'Predict'
)

Button_widget = widgets.Button(
    description = 'Predict'
)

prediction_out = widgets.Output()


def make_prediction(btn):
  x = pd.DataFrame({
      'age':      Age_widget.value,
      'sex':      Sex_widget.value,
      'bmi':      Bmi_widget.value,
      'children': Childrens_widget.value,
      'smoker':   Smoker_widget.value,
      'region':   Region_widget.value
  },index = [0])

  prediction = GB_model.predict(x)

  with prediction_out:
    prediction_out.clear_output()
    print('Your Insurance Premium Per Year is Rs:',format(prediction[0]))



Button_widget.on_click(make_prediction)

# %%
display(Age_widget,Bmi_widget,Childrens_widget, Sex_widget, Smoker_widget, Region_widget, Button_widget, prediction_out)
# Out:
# IntSlider(value=18, description='AGE:', max=60, min=10)
# FloatSlider(value=30.0, description='BMI: ', max=54.0, min=15.0, step=0.01)
# IntSlider(value=1, description="CHILDREN'S:", max=10)
# ToggleButtons(description='SEX: ', options=('female', 'male'), value='female')
# ToggleButtons(description='SMOKER: ', options=('no', 'yes'), value='no')
# Dropdown(description='REGION: ', options=('northwest', 'southwest', 'northeast', 'southeast'), value='northwes…
# Button(description='Predict', style=ButtonStyle())
# Output()
